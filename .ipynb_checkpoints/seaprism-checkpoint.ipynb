# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.dates import DayLocator, DateFormatter
from datetime import datetime
dateparse = lambda x, y: datetime.strptime(str(x)+str(y), '%d:%m:%Y%H:%M:%S')

# %% [markdown]
# # Aeronet Level 1.0 (10) or 1.5 (15) for LO

# %%
def get_seaprism(start='2021-01-01', stop='now', level=10):
    start = pd.to_datetime(start)
    if stop == 'now':
        stop = datetime.now()
    else:
        stop = pd.to_datetime(stop)
    y1, m1, d1 = start.year, start.month, start.day
    y2, m2, d2 = stop.year, stop.month, stop.day

    base = 'https://aeronet.gsfc.nasa.gov/cgi-bin/print_web_data_v3?site=Lake_Okeechobee_N'
    time = 'year=%i&month=%i&day=%i&year2=%i&month2=%i&day2=%i' % (y1, m1, d1, y2, m2, d2)
    level = 'LWN%i=1&AVG=10' % level
    url = '&'.join([base, time, level])
    df = pd.read_csv(url, skiprows=7, skipfooter=1, parse_dates={'datetime': ['Date(dd-mm-yyyy)','Time(hh:mm:ss)']},
                 date_parser=dateparse, engine='python')
    df.set_index('datetime', inplace=True)
    return df

# %%
df = get_seaprism()
# Out:
# /Users/hboi/miniconda3/envs/owl/lib/python3.7/site-packages/pandas/io/parsers.py:3339: FutureWarning:
#         Use pd.to_datetime instead.
#
#   return generic_parser(date_parser, *date_cols)

# %% [markdown]
# # F0 [Thuillier (2003) solar spectrum]

# %%
F0 = pd.read_csv('https://oceancolor.gsfc.nasa.gov/docs/rsr/f0.txt',  encoding='iso-8859-1', sep=r'\s{1,}', 
                 skiprows=15, names= ['wavelength', 'irradiance'], index_col='wavelength', engine='python')
fig, ax = plt.subplots()
F0.plot(ax=ax)
F0.loc[[667, 681, 709]].plot(marker='o', linestyle = 'None', ax=ax)
# Out:
# <AxesSubplot:xlabel='wavelength'>

# %% [markdown]
# # Rrs = LwN/F0 where LwN is the normalized water leaving radiance and F0 is the extra-terrestrial solar irradiation (both are spectral)

# %% [markdown]
# Rrs $= \frac{Lwn}{F0} => \frac{mW}{cm^2\ sr\ um} \times \frac{cm^2\ nm}{uW} \times \frac{1000\ uW}{mW} \times \frac{um}{1000nm} = \frac{1}{sr} $

# %% [markdown]
# Lwn $=> \frac{mW}{cm^2\ sr\ nm} \quad \textrm{and} \quad F0 => \frac{uW}{cm^2\ nm}$

# %%
def calc_Rrs(LwN, F0):
    return LwN/F0

def calc_CI(Rrs681, Rrs667, Rrs709):
    return -(Rrs681 - Rrs667 - (Rrs709 - Rrs667)*((681-664)/(709-664)))

def load_F0():
    return pd.read_csv('https://oceancolor.gsfc.nasa.gov/docs/rsr/f0.txt',  encoding='iso-8859-1', sep=r'\s{1,}', 
                 skiprows=15, names= ['wavelength', 'irradiance'], index_col='wavelength', engine='python')

def get_CI(df, average=True):
    ## CI = -(Rrs681 - Rrs667 - (Rrs709 - Rrs667)*((681-664)/(709-664)));
    wls = [667, 681, 709]
    F0 = load_F0()
    for wl in wls:
        Rrs_name = 'Rrs[%snm]' % wl
        print(Rrs_name)
        if Rrs_name not in df.columns:
            if average:
                i=int(wl/10)*10
                print(i, i+9)
#                 F0_ = F0.loc[i:i+9].mean().values
                F0_ = F0.loc[660:669].mean().values
            else:
                F0_ = F0.loc[wl].values
            df[Rrs_name] = calc_Rrs(df['Lwn[%snm]' % str(wl)], F0_)
    return calc_CI(df['Rrs[681nm]'], df['Rrs[667nm]'], df['Rrs[709nm]'])

# %%
df['CI'] = get_CI(df)
# Out:
# Rrs[667nm]
# 660 669
# Rrs[681nm]
# 680 689
# Rrs[709nm]
# 700 709

# %%
fig, ax = plt.subplots(figsize=(10,3))
cax = fig.add_axes([.55, .8, .3, .05])
subset = df.loc[df['CI']>=0]
im = ax.scatter(subset.index, subset['Rrs[709nm]'], c=subset['CI'], cmap='viridis', vmin=0, vmax=.005)

df.loc[df['CI']<0].reset_index().plot(kind='scatter', x='datetime', y='Rrs[709nm]', c='none', edgecolor='DarkBlue', ax=ax)
# CI.plot(marker='o', linestyle='none')
ax.set_xlim(pd.to_datetime('2021-08-10'), pd.to_datetime('2021-09-17'))
ax.set_ylim(0, .02)
ax.set_xlabel('')
ax.xaxis.set_major_locator(DayLocator(interval=3))
ax.xaxis.set_minor_locator(DayLocator(interval=1))
ax.xaxis.set_major_formatter(DateFormatter('%d %b'))
cb = fig.colorbar(im, cax=cax, orientation='horizontal')
cb.set_label('CI [non dimensional]')
fig.savefig('/Users/hboi/Desktop/seaprism.png')

# %%
for col in df.columns:
    print(col)
# Out:
# AERONET_Site
# Day_of_Year
# Day_of_Year(Fraction)
# Solar_Zenith_Angle[340nm]
# Solar_Zenith_Angle[380nm]
# Solar_Zenith_Angle[400nm]
# Solar_Zenith_Angle[412nm]
# Solar_Zenith_Angle[440nm]
# Solar_Zenith_Angle[443nm]
# Solar_Zenith_Angle[490nm]
# Solar_Zenith_Angle[500nm]
# Solar_Zenith_Angle[510nm]
# Solar_Zenith_Angle[531nm]
# Solar_Zenith_Angle[532nm]
# Solar_Zenith_Angle[551nm]
# Solar_Zenith_Angle[555nm]
# Solar_Zenith_Angle[560nm]
# Solar_Zenith_Angle[620nm]
# Solar_Zenith_Angle[667nm]
# Solar_Zenith_Angle[675nm]
# Solar_Zenith_Angle[681nm]
# Solar_Zenith_Angle[709nm]
# Solar_Zenith_Angle[779nm]
# Solar_Zenith_Angle[865nm]
# Solar_Zenith_Angle[870nm]
# Solar_Zenith_Angle[1020nm]
# Solar_Zenith_Angle[Empty]
# Solar_Zenith_Angle[Empty].1
# Solar_Zenith_Angle[Empty].2
# Solar_Zenith_Angle[Empty].3
# Solar_Zenith_Angle[Empty].4
# Solar_Azimuth_Angle[340nm]
# Solar_Azimuth_Angle[380nm]
# Solar_Azimuth_Angle[400nm]
# Solar_Azimuth_Angle[412nm]
# Solar_Azimuth_Angle[440nm]
# ...
